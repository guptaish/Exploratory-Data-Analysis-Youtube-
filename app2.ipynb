# %%
import numpy as np
import pandas as pd
data=pd.read_csv('Datasets/INvideos.csv')
data

#Cleaning Data
dlt=['trending_date','video_error_or_removed','comments_disabled','thumbnail_link','ratings_disabled']
data=data.drop(dlt,axis=1)
data.info()

#removing duplicates
data=data.drop_duplicates(keep='first')
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37352 entries, 0 to 37351
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37352 non-null  object
#  1   title          37352 non-null  object
#  2   channel_title  37352 non-null  object
#  3   category_id    37352 non-null  int64
#  4   publish_time   37352 non-null  object
#  5   tags           37352 non-null  object
#  6   views          37352 non-null  int64
#  7   likes          37352 non-null  int64
#  8   dislikes       37352 non-null  int64
#  9   comment_count  37352 non-null  int64
#  10  description    36791 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 2.3+ MB
#           video_id                                              title  \
# 0      kzwfHumJyYc  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...
# 1      zUZ1z7FwLc8  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2      10L1hZ9qa58  Stylish Star Allu Arjun @ ChaySam Wedding Rece...
# 3      N1vE8iiEg64                     Eruma Saani | Tamil vs English
# 4      kJzGH0PVQHQ  why Samantha became EMOTIONAL @ Samantha naga ...
# ...            ...                                                ...
# 37300  UPbi1oG5UPg  Engineering Girls | Web Series | S01E02 - Ghar...
# 37301  3MTCSll3KGU  Rusev vs. Samoa Joe - with Special Guest Refer...
# 37302  TIE92mUvSsw  Dhadak | Official Trailer | Janhvi & Ishaan | ...
# 37319  1-0mS2ZBrQk                   What If PubG Was Made In India ?
# 37330  K10YIAokjvE  Funny Ramzan Scenes Part - 2 | Hyderabadi Come...
#
#             channel_title  category_id              publish_time  \
# 0         Lokdhun Punjabi            1  2017-11-12T12:20:39.000Z
# 1                 HJ NEWS           25  2017-11-13T05:43:56.000Z
# 2                    TFPC           24  2017-11-12T15:48:08.000Z
# 3             Eruma Saani           23  2017-11-12T07:08:48.000Z
# 4              Filmylooks           24  2017-11-13T01:14:16.000Z
# ...                   ...          ...                       ...
# 37300      The Timeliners           24  2018-06-08T13:54:39.000Z
# 37301                 WWE           17  2018-06-13T03:09:21.000Z
# 37302  Dharma Productions            1  2018-06-11T06:50:41.000Z
# 37319         Angry Prash           23  2018-06-11T08:37:21.000Z
# 37330    Warangal Diaries           23  2018-06-13T10:16:21.000Z
#
#                                                     tags     views   likes  \
# 0      sharry mann|"sharry mann new song"|"sharry man...   1096327   33966
# 1      पीरियड्स के समय|"पेट पर पति करता ऐसा"|"देखकर द...    590101     735
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...    473988    2011
# 3      Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...   1242680   70353
# 4      Filmylooks|"latest news"|"telugu movies"|"telu...    464015     492
# ...                                                  ...       ...     ...
# 37300  funny videos|"hotels"|"comedy"|"comedy video"|...   2675706   96485
# 37301  wwe|"world wrestling entertainment"|"wrestling...    770873   13316
# 37302  Dharma|"Dharma Productions"|"Dhadak"|"Janhvi K...  27696924  468472
# 37319  pubg|"PlayerUnknown's Battlegrounds"|"pubg mob...   1214423   85601
# 37330  warangal diaries|"latest"|"funny"|"comedy"|"Ba...    132055   11170
#
#        dislikes  comment_count  \
# 0           798            882
# 1           904              0
# 2           243            149
# 3          1624           2684
# 4           293             66
# ...         ...            ...
# 37300      4181           6634
# 37301       552           1175
# 37302     60025          48740
# 37319      4677           7628
# 37330       393           2107
#
#                                              description
# 0      Presenting Sharry Mann latest Punjabi Song  Cu...
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2      Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 3      This video showcases the difference between pe...
# 4      why Samantha became EMOTIONAL @ Samantha naga ...
# ...                                                  ...
# 37300  Maggu is preparing for Sharda University inter...
# 37301  The Miz serves as special guest referee in thi...
# 37302  When two worlds collide, they become oneDhadak...
# 37319  This funny video is about what if players unkn...
# 37330  (Earphone Use Is Recommended)!!Funny Ramzan Sc...
#
# [33089 rows x 11 columns]

# %%
#Exploratory Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(data)
plt.show()

# %%
columns_of_interest = ['views', 'likes', 'dislikes','comment_count']
corr_matrix = data[columns_of_interest].corr()
corr_matrix
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.852704  0.551652       0.697749
# likes          0.852704  1.000000  0.499926       0.792815
# dislikes       0.551652  0.499926  1.000000       0.740269
# comment_count  0.697749  0.792815  0.740269       1.000000

# %%
#Top viewed video

# %%
top=data.sort_values(by=['views'],ascending=False)
top=top.drop_duplicates(subset='video_id',keep='first')
top=top.head(10)

print(top[['title','views']])
plt.bar(top['title'],top['views'])
plt.xticks(rotation=90)
plt.show()
# Out:
#                                                    title      views
# 5408   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  125432237
# 4477   Marvel Studios' Avengers: Infinity War Officia...   89930713
# 29298                      VENOM - Official Trailer (HD)   53822757
# 22949  Marvel Studios' Avengers: Infinity War - Offic...   45064699
# 29668  Sanju | Official Teaser | Ranbir Kapoor | Rajk...   44171797
# 22309                            Taylor Swift - Delicate   43738208
# 12044     Taylor Swift - End Game ft. Ed Sheeran, Future   42019590
# 3045   Swag Se Swagat Song | Tiger Zinda Hai | Salman...   40953758
# 377          Ed Sheeran - Perfect (Official Music Video)   39082222
# 545    Tiger Zinda Hai | Official Trailer | Salman Kh...   38664360

# %%
#Most Liked video

# %%
liked=top=data.sort_values(by=['likes'],ascending=False)
liked=liked.drop_duplicates(subset='video_id',keep='first')
liked=liked.head(10)
plt.bar(liked['title'],liked['likes'])
plt.xticks(rotation=90)
plt.show()

# %%
#Most disliked viedo

# %%
disliked=data.sort_values(by=['dislikes'],ascending=False)
disliked=disliked.drop_duplicates(subset='video_id',keep='first')
disliked=disliked.head(10)
plt.bar(disliked['title'],disliked['dislikes'])
plt.xticks(rotation=90)
plt.show()

# %%
#Most commented video

# %%
comments=data.sort_values(by=['comment_count'],ascending=False)
comments=disliked.drop_duplicates(subset='video_id',keep='first')
comments=comments.head(10)
plt.bar(comments['title'],comments['comment_count'])
plt.xticks(rotation=90)
plt.show()

# %%
#Top viewed channels

# %%
new=data.groupby('channel_title').sum().sort_values(by=['views'],ascending=False)
fig, ax = plt.subplots(figsize=(15,7))
new.plot(ax=ax)
new
# plt.plot(new['channel_title'],new['views'],c='green')
# plt.plot(new['channel_title'],new['likes'],c='black')
# plt.plot(new['channel_title'],new['dislikes'],c='orange')
# plt.show()
# Out:
#                            views     likes  dislikes  comment_count
# channel_title
# T-Series              1748057724  31812724   2196417        2163936
# Marvel Entertainment  1058174340  34188269    620004        4201145
# FoxStarHindi           982953616  19260709    764425        1422502
# Amit Bhadana           855533181  52376821   1902575        5480376
# Speed Records          648890913  17611166    836043        1191255
# ...                          ...       ...       ...            ...
# Pakkatv                    13443        51         8              9
# Reporter Roy               11816        27         5              1
# Viral in India             11391        34        14              2
# Wide Angle Pictures        11337       434        30             53
# News VIdeo                  7573         1         1              2
#
# [1426 rows x 4 columns]

# %%
#Adding Category column using json

# %%
categories_df = pd.read_json('Datasets/IN_category_id.json')

data['category_id'] = data['category_id'].astype(str)
id_to_category = {}
for category in categories_df['items']:
    id_to_category[category['id']] = category['snippet']['title']
data.insert(4, 'category', data['category_id'].map(id_to_category))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-3b83874858f2> in <module>
#       5 for category in categories_df['items']:
#       6     id_to_category[category['id']] = category['snippet']['title']
# ----> 7 data.insert(4, 'category', data['category_id'].map(id_to_category))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert category, already exists

# %%
cate=data.groupby('category').sum().sort_values(by=['views'],ascending=False)
fig, ax = plt.subplots(figsize=(15,7))
cate['views'].plot.bar(ax=ax,color=['r', 'g', 'b','orange','lightgreen'])
cate
# Out:
#                             views      likes  dislikes  comment_count
# category
# Entertainment         13326399551  328229550  23577924       35486403
# Music                  8336504205  213063323  12072772       14558095
# Film & Animation       3273144924   57790703   3645206        4844060
# Comedy                 2423485988  146425199   5723206       11560689
# News & Politics        1658578208   13449502   2286562        2535027
# Sports                 1192613734   28473825   1088494        2346624
# People & Blogs         1146217515   19883239   1487089        2331943
# Howto & Style           674464823    7247108    774931         693467
# Science & Technology    435729557   18121097    818134        7580486
# Gaming                  198350285    5100129    243440         485860
# Education               132322235    6843999    226840         874977
# Shows                    99079954     547324    163989          77939
# Movies                   31919530     409750     21902          22962
# Autos & Vehicles         26439304     488917     19769          86488
# Pets & Animals            4879743     362534      6488          42056
# Travel & Events           1374342      16939       616           2448
